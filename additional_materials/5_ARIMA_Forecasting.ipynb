# %% [markdown]
# HSE, Applied Time Series Forecasitng , Fall2024
#
# <font color="green"> Lesson #5: TS Foreasting using ARIMA Models </font>
#
# <span style="color:black; font-size: 12pt"></span>
#
# Alexey Romanenko,
# <font color="blue">alexromsput@gmail.com</font>

# %% [markdown]
# **Key words:**
#     - stationary TS, ARMA, ARIMA, ARMAX, SARIMAX, autocorrelcation function,  partial autocorrelation function, exogenious variables,
# **Your feedback:**  please provide you feedback  <a href="https://forms.gle/bEV5iwmTqdM9rUoy8"> here </a>

# %%
import numpy as np
import pandas as pd
from datetime import timedelta
from scipy import stats
import statsmodels.api as sm
from statsmodels.tsa import stattools
from copy import deepcopy

# don't forget to upload utils file to the colab session
from utils import qualityMAPE, qualityRMSE
import warnings
warnings.filterwarnings('ignore')

pd.options.plotting.backend = "plotly"

# setting of the plotting style, registers pandas date converters for matplotlib and the default figure size
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")
# pd.plotting.register_matplotlib_converters()
# Default figure size
sns.mpl.rc("figure", figsize=(25, 5))
sns.mpl.rc("font", size=14)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       7 from copy import deepcopy
#       9 # don't forget to upload utils file to the colab session
# ---> 10 from utils import qualityMAPE, qualityRMSE
#      11 import warnings
#      12 warnings.filterwarnings('ignore')
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# # ARIMA Parameters
# **Questions**
#   * How to make TS stationary?
#   * Write down formula that describes how the tranformed ts will look like (use lag operator $\bf B$).

# %% [markdown]
# **Answer**
# $${\bf(1-B)^d(1-B^s)^D} {\bf BoxCox_{\lambda}} (y_t)$$
# where $s~-$ seasonality period

# %% [markdown]
# ## ARIMA model for non-stationary time series
# In order to make ts stationary we apply trend ${\bf(1-\bf B)}$ differencing $d$ times and seasonal ${\bf(1-B^s)}$ differencing $D$ times.
#
#
# **Main hypothesys**: exists $d$, $D$, $\lambda$ such that
#
#   * $$ {\bf(1-B)^d(1-B^s)^D} {\bf BoxCox_{\lambda}} (y_t)~- \text{ stationary} $$

# %% [markdown]
# Final ts model:
# * Lets denote: ${\bf BoxCox_{\lambda}} (y_t) = z_t$
# * classic form:
# $$\color{red}{\underbrace{\bf(1-B)^d(1-B^s)^D}\limits_{I}}z_t = \underbrace{c+\sum_{i=1}^{p}}\limits_{AR} \alpha_iz_{t-i}+\underbrace{\sum_{j=1}^{q}}\limits_{MA} \beta_j\varepsilon_{t-j}+\varepsilon_t$$
#
# * or in canonical form:
#
# $$\underbrace{\phi\left({\bf B}\right)}\limits_{AR}\color{red}{\underbrace{\bf(1-B)^d(1-B^s)^D}\limits_{I}}(z_t-\mu) = \underbrace{\theta\left(\bf B\right)}\limits_{MA}\varepsilon_t.$$
#
# * $\varepsilon_t$- random variable from $N(0, \sigma^2)$, $E\varepsilon_t=0, ~E\varepsilon_i\varepsilon_j=0$

# %% [markdown]
# # Fitting Parameters of ARIMA model
#
# Classic form of ARIMA model implies that there are some seasonal Autoregressive Components and seasonal Moving Average Components
#
#
# $${\bf(1-B)^{\color{red}{d}}(1-B^s)^{\color{red}D}}z_t = \underbrace{c+\sum_{i=1}^{\color{red}p}}\limits_{AR} \alpha_iz_{t-i}+\underbrace{\sum_{j=1}^{\color{red}q}}\limits_{MA} \beta_j\varepsilon_{t-j}+\underbrace{\sum_{l=1}^{\color{red}P}}\limits_{seasonal~AR} \delta_lz_{t-\color{red}{s\cdot l}}+\underbrace{\sum_{m=1}^{\color{red}Q}}\limits_{seasonal~MA} \omega_m\varepsilon_{t-\color{red}{s*m}}+\varepsilon_t$$
#
#
# Classic ARIMA model contains 6 (hyper)parameters:
# $$ARIMA(p, d, q)\times(P, D, Q)_s$$
# where
#
#  - $p~-$ is a number of non-seasonal AR components
#  - $q~-$ is a number of non-seasonal MA components
#  - $d~-$ is a number of trend-differencing applied to make ts stationary
#  - $P~-$ is a number of seasonal AR components
#  - $Q~-$ is a number of seasonal MA components
#  - $D~-$ is a number of seasonal-differencing to make ts stationary

# %%
# Wage
ts_wage = pd.read_csv('https://raw.githubusercontent.com/aromanenko/ATSF/33b78c9be63831567f8036ad40c5859e824d30f7/data/monthly-wage.csv', sep=';', decimal='.', parse_dates=True, index_col='Month')
ts_wage.index.names=['Timestamp']
ts_wage.plot().update_layout(height=350, width=1300).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       2 ts_wage = pd.read_csv('https://raw.githubusercontent.com/aromanenko/ATSF/33b78c9be63831567f8036ad40c5859e824d30f7/data/monthly-wage.csv', sep=';', decimal='.', parse_dates=True, index_col='Month')
#       3 ts_wage.index.names=['Timestamp']
# ----> 4 ts_wage.plot().update_layout(height=350, width=1300).show()
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %% [markdown]
# ## Fitting of $\lambda$, $d$, $D$ parameters

# %%
ts_wage_boxcox = deepcopy(ts_wage)
# find optimal lambda
print('optimal lambda:', stats.boxcox(ts_wage['Real wage'])[1])

# Box_Cox transformation (see lesson 4 for details)
ts_wage_boxcox['wage_boxcox'] = np.log(ts_wage)
# ts_wage_boxcox['wage_boxcox'].plot()


# seasonal differencing
p = 12
sdiff_ts_wage_boxcox = (ts_wage_boxcox['wage_boxcox'] - ts_wage_boxcox['wage_boxcox'].shift(p))[p:]
# sdiff_ts_wage_boxcox.plot()

# trend differencing
diff_sdiff_ts_wage_boxcox = (sdiff_ts_wage_boxcox  - sdiff_ts_wage_boxcox .shift(1))[1:]
diff_sdiff_ts_wage_boxcox.plot()

# Kwiatkowski–Phillips–Schmidt–Shin
kpss_stat= stattools.kpss(np.array(diff_sdiff_ts_wage_boxcox))
print('The KPSS test statistic %f, \npvalue: %.2f \nmaximal Lag: %i \ntable distribution: %s' %
      (kpss_stat[0], kpss_stat[1], kpss_stat[2], kpss_stat[3]))

# Augmented Dickey-Fuller unit root test
df_stat = stattools.adfuller(np.array(diff_sdiff_ts_wage_boxcox))
print('The Augmented Dickey-Fuller test statistic %f, \npvalue: %.2f \nmaximal Lag: %i \ncritical values: %s' %
      (df_stat[0], df_stat[1], df_stat[2], df_stat[4]))
# Out:
# optimal lambda: 0.12682613733305872
# The KPSS test statistic 0.024144,
# pvalue: 0.10
# maximal Lag: 7
# table distribution: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The Augmented Dickey-Fuller test statistic -4.434243,
# pvalue: 0.00
# maximal Lag: 15
# critical values: {'1%': np.float64(-3.4557539868570775), '5%': np.float64(-2.8727214497041422), '10%': np.float64(-2.572728476331361)}
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11812\4285440231.py:20: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_stat= stattools.kpss(np.array(diff_sdiff_ts_wage_boxcox))

# %%
# Let's train our first ARMA(p,q) model
arma_mod00 = sm.tsa.ARIMA(diff_sdiff_ts_wage_boxcox, order=(0,0,0)).fit()
print(arma_mod00.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            wage_boxcox   No. Observations:                  276
# Model:                          ARIMA   Log Likelihood                 490.277
# Date:                Mon, 02 Dec 2024   AIC                           -976.554
# Time:                        18:02:46   BIC                           -969.313
# Sample:                    02-01-1994   HQIC                          -973.648
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.101      0.920      -0.005       0.005
# sigma2         0.0017   3.91e-05     42.871      0.000       0.002       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                  19.97   Jarque-Bera (JB):              6995.34
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.08   Skew:                            -0.11
# Prob(H) (two-sided):                  0.00   Kurtosis:                        27.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# **Questions**
#   * What should be done to forecast original wage ts?

# %%
# draw ARMA forecast and ts
pd.DataFrame(arma_mod00.get_prediction().predicted_mean['2000-01-01':]).merge(diff_sdiff_ts_wage_boxcox, how='left', right_index = True, left_index = True).plot().update_layout(height=350, width=1300).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # draw ARMA forecast and ts
# ----> 2 pd.DataFrame(arma_mod00.get_prediction().predicted_mean['2000-01-01':]).merge(diff_sdiff_ts_wage_boxcox, how='left', right_index = True, left_index = True).plot().update_layout(height=350, width=1300).show()
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %%
# Let's train our first ARIMA (p, d, q)x(P, D, Q, s) model
arima_010_010 = sm.tsa.SARIMAX(endog = ts_wage_boxcox['wage_boxcox'], order=(0, 1, 0), seasonal_order = (0,1,0,12)).fit()
print(arima_010_010.summary())

#  static predictions = one-step-ahead forecast
predict = arima_010_010.get_prediction()
forecast = pd.DataFrame(predict.predicted_mean).rename(columns = {'predicted_mean':'static_forecast'})
forecast_ci = predict.conf_int().rename(columns = {'lower wage_boxcox':'l_ci_st',	'upper wage_boxcox':'u_ci_st'}) # confidence interval


start_dt = '2000-01-01'

#  Dynamic predictions = n-step-ahead forecast
predict_dy = arima_010_010.get_prediction(dynamic=start_dt)
forecast_dy = pd.DataFrame(predict_dy.predicted_mean).rename(columns = {'predicted_mean':'dynamic_forecast'})
forecast_dy_ci = predict_dy.conf_int().rename(columns = {'lower wage_boxcox':'l_ci_dy',	'upper wage_boxcox':'u_ci_dy'}) # confidence interval


# Plot data points and predictions
ts_wage_boxcox.loc[start_dt:, ['wage_boxcox']].merge(
     forecast[start_dt:],
      how = 'left', left_index = True, right_index = True
      ).merge(
          forecast_dy[start_dt:],
          how = 'left', left_index = True, right_index = True
      ).merge(
        forecast_ci,
        how = 'left', left_index = True, right_index = True
      ).merge(
        forecast_dy_ci,
        how = 'left', left_index = True, right_index = True
      ).plot().update_layout(height=350, width=1300).show()
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                        wage_boxcox   No. Observations:                  289
# Model:             SARIMAX(0, 1, 0)x(0, 1, 0, 12)   Log Likelihood                 490.272
# Date:                            Mon, 02 Dec 2024   AIC                           -978.543
# Time:                                    18:04:40   BIC                           -974.923
# Sample:                                01-01-1993   HQIC                          -977.090
#                                      - 01-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0017   3.91e-05     42.883      0.000       0.002       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                  19.97   Jarque-Bera (JB):              6995.34
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.08   Skew:                            -0.11
# Prob(H) (two-sided):                  0.00   Kurtosis:                        27.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 32
#      16 forecast_dy_ci = predict_dy.conf_int().rename(columns = {'lower wage_boxcox':'l_ci_dy',	'upper wage_boxcox':'u_ci_dy'}) # confidence interval
#      19 # Plot data points and predictions
#      20 ts_wage_boxcox.loc[start_dt:, ['wage_boxcox']].merge(
#      21      forecast[start_dt:],
#      22       how = 'left', left_index = True, right_index = True
#      23       ).merge(
#      24           forecast_dy[start_dt:],
#      25           how = 'left', left_index = True, right_index = True
#      26       ).merge(
#      27         forecast_ci,
#      28         how = 'left', left_index = True, right_index = True
#      29       ).merge(
#      30         forecast_dy_ci,
#      31         how = 'left', left_index = True, right_index = True
# ---> 32       ).plot().update_layout(height=350, width=1300).show()
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %%
def draw_arima_forecast(ts, arima_model, start_dt=0, end_dt=-1):
  predict = arima_model.get_prediction()
  forecast = pd.DataFrame(predict.predicted_mean).rename(columns = {'predicted_mean':'static_forecast'})
  forecast_ci = predict.conf_int().rename(columns = {'lower wage_boxcox':'l_ci_st',	'upper wage_boxcox':'u_ci_st'}) # confidence interval

  #  Dynamic predictions
  predict_dy = arima_model.get_prediction(dynamic=start_dt)
  forecast_dy = pd.DataFrame(predict_dy.predicted_mean).rename(columns = {'predicted_mean':'dynamic_forecast'})
  forecast_dy_ci = predict_dy.conf_int().rename(columns = {'lower wage_boxcox':'l_ci_dy',	'upper wage_boxcox':'u_ci_dy'}) # confidence interval

  if start_dt ==0:
    start_dt= ts.index.min()

  if end_dt == -1:
    end_dt = ts_wage_boxcox.index.max()

  # Plot data points and predictions
  fig = ts.loc[start_dt:].merge(
      forecast[start_dt:end_dt],
        how = 'left', left_index = True, right_index = True
        ).merge(
            forecast_dy[start_dt:],
            how = 'left', left_index = True, right_index = True
        ).merge(
          forecast_ci,
          how = 'left', left_index = True, right_index = True
        ).merge(
          forecast_dy_ci,
          how = 'left', left_index = True, right_index = True
        ).plot().update_layout(height=350, width=1300).show()

  return fig

# draw_arima_forecast(ts_wage_boxcox[['wage_boxcox']], arima_010_010, start_dt='2000-01-01', end_dt=-1)

# %% [markdown]
# ## Fitting of $q$, $Q$ and $p$, $P$ parameters

# %% [markdown]
#
# **Autocorrelation coeficient:**
# *  $$ r_\tau = r_{y_t y_{t+\tau}} = \frac{\sum\limits_{t=1}^{T-\tau} \left(y_t - \bar{y}\right)\left(y_{t+\tau} - \bar{y}\right) }{ \sum\limits_{t=1}^T \left(y_t - \bar{y}\right)^2 },\;\; \bar{y} = \frac1{T} \sum_{t=1}^T y_t.$$
#
# $r_\tau \in\left[-1,1\right], \;\; \tau$ - autocorrelation lag.

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ts_wage_boxcox['wage_boxcox'], lags=40, ax= ax1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 fig = plt.figure()
#       2 ax1 = fig.add_subplot(211)
#       3 fig = sm.graphics.tsa.plot_acf(ts_wage_boxcox['wage_boxcox'], lags=40, ax= ax1)
#
# NameError: name 'plt' is not defined

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(diff_sdiff_ts_wage_boxcox, lags=40, ax = ax1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 fig = plt.figure()
#       2 ax1 = fig.add_subplot(211)
#       3 fig = sm.graphics.tsa.plot_acf(diff_sdiff_ts_wage_boxcox, lags=40, ax = ax1)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **Coefficient of partial correlation:** between $y$, $x_1$ excluding dependence on $x_2$:
# <img src='https://github.com/aromanenko/ATSF/blob/main/pic/PACF.PNG?raw=1'>
#
# * <font color="red">Coefficient of partial correlation</font> shows correlation between $y_t$ and $y_{t+\tau}$, <font color=""> excluding dependence </font>
#    - between $y_t$ and $y_{t+1}$ ($y_{t+\tau}$ and $y_{t+1}$)
#    - between $y_t$ and $y_{t+2}$ ($y_{t+\tau}$ and $y_{t+2}$)
#
#    ...
#
#    - between $y_t$ and $y_{t+\tau-1}$ ($y_{t+\tau}$ and $y_{t+\tau-1}$)
#
#
# *  see here  <a href="https://timeseriesreasoning.com/contents/partial-auto-correlation"> here </a> for details

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(diff_sdiff_ts_wage_boxcox, lags=40, ax = ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(diff_sdiff_ts_wage_boxcox, lags=40, ax=ax2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 fig = plt.figure()
#       2 ax1 = fig.add_subplot(211)
#       3 fig = sm.graphics.tsa.plot_acf(diff_sdiff_ts_wage_boxcox, lags=40, ax = ax1)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **How to select candidates for $q$ and $Q$ based on ACF?**
#
# *Answer*:
# * $q$: the number of the last lag $\tau<S$ at which <span style="color:red"> ACF </span> was significant ($S$ - period of seasonality)
# * $Q$: the lag numbers $\tau= s*m$ that are multiples of the seasonality period $s$: at which <span style="color:red"> ACF </span> was significant
#
# **How to select candidates for $p$ and $P$ based on PACF?**
#
# *Answer*:
#
# * $p$: the number of the last lag $\tau<S$ at which <span style="color:red">PACF</span> was significant at which <span style="color:red"> PACF </span> was significant
# * $P$: he lag numbers $\tau= s*m$ that are multiples of the seasonality period at which <span style="color:red">PACF</span> was significant at which <span style="color:red"> PACF </span> was significant

# %% [markdown]
# **Question**:
# * Provide candidates for $q, Q, p, P$ values in case of the wage_ts
#   * $q$ = {1, 2, 3, 4}
#   * $Q$ = {1}
#   * $p$ = {1}
#   * $P$ = {1, 2, 3}

# %%
# Let's train the second ARMA model
arma_mod11 = sm.tsa.ARIMA(diff_sdiff_ts_wage_boxcox, order = (1,0, 1)).fit()
print(arma_mod11.summary())

draw_arima_forecast(pd.DataFrame(diff_sdiff_ts_wage_boxcox), arma_mod11, start_dt='2014-12-01', end_dt='2017-12-01')
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            wage_boxcox   No. Observations:                  276
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                 502.552
# Date:                Mon, 02 Dec 2024   AIC                           -997.104
# Time:                        18:05:12   BIC                           -982.622
# Sample:                    02-01-1994   HQIC                          -991.293
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.004      0.048      0.961      -0.008       0.008
# ar.L1          0.6800      0.131      5.183      0.000       0.423       0.937
# ma.L1         -0.4570      0.156     -2.934      0.003      -0.762      -0.152
# sigma2         0.0015   4.75e-05     32.274      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              6407.83
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.10   Skew:                            -0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                        26.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 5
#       2 arma_mod11 = sm.tsa.ARIMA(diff_sdiff_ts_wage_boxcox, order = (1,0, 1)).fit()
#       3 print(arma_mod11.summary())
# ----> 5 draw_arima_forecast(pd.DataFrame(diff_sdiff_ts_wage_boxcox), arma_mod11, start_dt='2014-12-01', end_dt='2017-12-01')
#
# Cell In[7], line 30, in draw_arima_forecast(ts, arima_model, start_dt, end_dt)
#      15   end_dt = ts_wage_boxcox.index.max()
#      17 # Plot data points and predictions
#      18 fig = ts.loc[start_dt:].merge(
#      19     forecast[start_dt:end_dt],
#      20       how = 'left', left_index = True, right_index = True
#      21       ).merge(
#      22           forecast_dy[start_dt:],
#      23           how = 'left', left_index = True, right_index = True
#      24       ).merge(
#      25         forecast_ci,
#      26         how = 'left', left_index = True, right_index = True
#      27       ).merge(
#      28         forecast_dy_ci,
#      29         how = 'left', left_index = True, right_index = True
# ---> 30       ).plot().update_layout(height=350, width=1300).show()
#      32 return fig
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %%
# Let's train the second ARIMA(p,d,q)x(P, D, Q) model
arima_011_311 = sm.tsa.SARIMAX(endog = ts_wage_boxcox['wage_boxcox'], order=(0, 1, 1), seasonal_order = (3,1,1,12)).fit()
print(arima_011_311.summary())

draw_arima_forecast(ts_wage_boxcox[['wage_boxcox']], arima_011_311, start_dt='2008-01-01', end_dt='2017-12-01')
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                        wage_boxcox   No. Observations:                  289
# Model:             SARIMAX(0, 1, 1)x(3, 1, 1, 12)   Log Likelihood                 555.495
# Date:                            Mon, 02 Dec 2024   AIC                          -1098.991
# Time:                                    18:05:47   BIC                          -1077.269
# Sample:                                01-01-1993   HQIC                         -1090.274
#                                      - 01-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.1667      0.049      3.400      0.001       0.071       0.263
# ar.S.L12      -0.3063      0.182     -1.683      0.092      -0.663       0.050
# ar.S.L24      -0.1875      0.133     -1.406      0.160      -0.449       0.074
# ar.S.L36      -0.2058      0.076     -2.707      0.007      -0.355      -0.057
# ma.S.L12      -0.4237      0.189     -2.239      0.025      -0.794      -0.053
# sigma2         0.0010   3.32e-05     30.430      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):              7368.72
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.21   Skew:                            -2.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                        27.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 5
#       2 arima_011_311 = sm.tsa.SARIMAX(endog = ts_wage_boxcox['wage_boxcox'], order=(0, 1, 1), seasonal_order = (3,1,1,12)).fit()
#       3 print(arima_011_311.summary())
# ----> 5 draw_arima_forecast(ts_wage_boxcox[['wage_boxcox']], arima_011_311, start_dt='2008-01-01', end_dt='2017-12-01')
#
# Cell In[7], line 30, in draw_arima_forecast(ts, arima_model, start_dt, end_dt)
#      15   end_dt = ts_wage_boxcox.index.max()
#      17 # Plot data points and predictions
#      18 fig = ts.loc[start_dt:].merge(
#      19     forecast[start_dt:end_dt],
#      20       how = 'left', left_index = True, right_index = True
#      21       ).merge(
#      22           forecast_dy[start_dt:],
#      23           how = 'left', left_index = True, right_index = True
#      24       ).merge(
#      25         forecast_ci,
#      26         how = 'left', left_index = True, right_index = True
#      27       ).merge(
#      28         forecast_dy_ci,
#      29         how = 'left', left_index = True, right_index = True
# ---> 30       ).plot().update_layout(height=350, width=1300).show()
#      32 return fig
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %% [markdown]
# **What else can be done?**
# ## Residuals Analysis
# **Questions**:
# * How to check all assumptions around ARIMA model?
#   - Unbiasedness ($\mathbf{E}\varepsilon_t = 0$): Wilcoxon or Student.
#   - No autocorrelation in residuals ($\mathbf{E}\varepsilon_t \varepsilon_{t+\tau} = 0$): correlogram analysis, Ljung-Box Q-test, Durbin-Watson.
#   - Normality ($\varepsilon_t \in N(0, \sigma)$): q-q plot, Shapiro-Wilk test.
#   - Stationarity ($\varepsilon_t$ belong to the same distibution $\forall t$)  visual analysis, KPSS, Dickey-Fuller.

# %%
arima_011_311.resid
# Out:
# Timestamp
# 1993-01-01    4.605170
# 1993-02-01   -0.009646
# 1993-03-01    0.027192
# 1993-04-01    0.078219
# 1993-05-01    0.048076
#                 ...
# 2016-09-01   -0.004831
# 2016-10-01   -0.016042
# 2016-11-01    0.006605
# 2016-12-01    0.008280
# 2017-01-01    0.020083
# Length: 289, dtype: float64

# %%
# plot residuals
pd.DataFrame(arima_011_311.resid).plot().update_layout(height=350, width=1300).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 # plot residuals
# ----> 2 pd.DataFrame(arima_011_311.resid).plot().update_layout(height=350, width=1300).show()
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %% [markdown]
# ### Autocorrelation test

# %%
# Autocorrelation analysis of residuals
fig = plt.figure()
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(arima_011_311.resid.values, lags=40, ax = ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(arima_011_311.resid.values, lags=40, ax=ax2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Autocorrelation analysis of residuals
# ----> 2 fig = plt.figure()
#       3 ax1 = fig.add_subplot(211)
#       4 fig = sm.graphics.tsa.plot_acf(arima_011_311.resid.values, lags=40, ax = ax1)
#
# NameError: name 'plt' is not defined

# %%
# Ljung-Box test
# H0: there is no correlcation for lag
pd.DataFrame({'lags':range(30), 'pvalue':sm.stats.diagnostic.acorr_ljungbox(arima_011_311.resid.values, lags=30)['lb_pvalue'],
              'critial':np.array([0.05]*30)}).set_index('lags').plot().update_layout(height=350, width=1300).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 4
#       1 # Ljung-Box test
#       2 # H0: there is no correlcation for lag
#       3 pd.DataFrame({'lags':range(30), 'pvalue':sm.stats.diagnostic.acorr_ljungbox(arima_011_311.resid.values, lags=30)['lb_pvalue'],
# ----> 4               'critial':np.array([0.05]*30)}).set_index('lags').plot().update_layout(height=350, width=1300).show()
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %% [markdown]
# It seems that LL lags for $\tau>12$ are correlated

# %% [markdown]
# # ARIMA forecast for Retail Time Series

# %%
ts = pd.read_csv('https://raw.githubusercontent.com/aromanenko/ATSF/main/data/retail_10ts.csv', sep=',', decimal='.', parse_dates=True, dayfirst=True, index_col='Dates')
ts.index.names=['Timestamp']
ts = ts.sort_index() # sort index
# ts.head()
dta = ts[ts.columns[0]].dropna()
dta.plot().update_layout(height=350, width=1300).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 6
#       4 # ts.head()
#       5 dta = ts[ts.columns[0]].dropna()
# ----> 6 dta.plot().update_layout(height=350, width=1300).show()
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %% [markdown]
# It can be assumed that TS is stationary

# %% [markdown]
# **Question**
#    * Select candidates for $p$ and $q$ values for ARMA model

# %%
# Use Item 165
fig = plt.figure()
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(dta.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(dta.values.squeeze(), lags=40, ax=ax2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Use Item 165
# ----> 2 fig = plt.figure()
#       3 ax1 = fig.add_subplot(211)
#       4 fig = sm.graphics.tsa.plot_acf(dta.values.squeeze(), lags=40, ax=ax1)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Let's try
# * $q$ = {0, 6}
# * $p$ = {0, 6}

# %%
# ARMA (p=0, q=0)
arma_mod00 = sm.tsa.ARIMA(dta, order=(0,0,0)).fit()
print(arma_mod00.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Item:  165   No. Observations:                  684
# Model:                          ARIMA   Log Likelihood               -1647.819
# Date:                Mon, 02 Dec 2024   AIC                           3299.638
# Time:                        18:07:06   BIC                           3308.694
# Sample:                             0   HQIC                          3303.143
#                                 - 684
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.9108      0.126     30.944      0.000       3.663       4.159
# sigma2         7.2450      0.273     26.539      0.000       6.710       7.780
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):               744.06
# Prob(Q):                              0.85   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.80   Skew:                             1.45
# Prob(H) (two-sided):                  0.09   Kurtosis:                         7.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# ARMA (p=0, q=6)
arma_mod06 = sm.tsa.ARIMA(dta, order = (0,0, 6)).fit()
print(arma_mod06.params)
print(arma_mod06.llf, arma_mod06.aic, arma_mod06.bic, arma_mod06.hqic)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# const     3.916451
# ma.L1    -0.014767
# ma.L2     0.019733
# ma.L3     0.050568
# ma.L4     0.044441
# ma.L5    -0.038890
# ma.L6     0.099284
# sigma2    7.129747
# dtype: float64
# -1642.3704846351184 3300.7409692702367 3336.964632611217 3314.7584760094114

# %%
# ARMA (p=6, q=0)
arma_mod60 = sm.tsa.ARIMA(dta, order = (6,0, 0)).fit()
print(arma_mod60.params)
print(arma_mod60.llf, arma_mod60.aic, arma_mod60.bic, arma_mod60.hqic)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# const     3.917934
# ar.L1    -0.006385
# ar.L2     0.014421
# ar.L3     0.050958
# ar.L4     0.058123
# ar.L5    -0.031952
# ar.L6     0.094307
# sigma2    7.126053
# dtype: float64
# -1642.2048472622 3300.4096945244 3336.6333578653803 3314.4272012635747

# %%
# ARMA (p=6, q=6)
arma_mod66 = sm.tsa.ARIMA(dta, order = (6,0, 6)).fit()
print(arma_mod66.params)
print(arma_mod66.llf, arma_mod66.aic, arma_mod66.bic, arma_mod66.hqic)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# const     3.957160
# ar.L1     0.244116
# ar.L2     0.204880
# ar.L3     0.154223
# ar.L4     0.612765
# ar.L5     0.180773
# ar.L6    -0.435855
# ma.L1    -0.255859
# ma.L2    -0.175029
# ma.L3    -0.153581
# ma.L4    -0.625143
# ma.L5    -0.219337
# ma.L6     0.517659
# sigma2    6.954595
# dtype: float64
# -1633.3673896935497 3294.7347793870995 3358.126190233815 3319.265416180655
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# ### Analyse Residuals to proof the model

# %%
# plot residuals
arma_mod06.resid.plot().update_layout(height=350, width=1300).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 # plot residuals
# ----> 2 arma_mod06.resid.plot().update_layout(height=350, width=1300).show()
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %% [markdown]
# ### Stationarity test

# %%
# Kwiatkowski–Phillips–Schmidt–Shin
kpss_stat= stattools.kpss(arma_mod06.resid.values)
print('The KPSS test statistic %f, \npvalue: %.2f \nmaximal Lag: %i \ntable distribution: %s' %
      (kpss_stat[0], kpss_stat[1], kpss_stat[2], kpss_stat[3]))
# Out:
# The KPSS test statistic 0.615316,
# pvalue: 0.02
# maximal Lag: 1
# table distribution: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}

# %% [markdown]
# It can be assumed that TS is stationary

# %% [markdown]
# ### Autocorrelation test

# %%
# Ljung-Box test
# H0: lags are not correlated
pd.DataFrame({'lags':range(30), 'pvalue':sm.stats.diagnostic.acorr_ljungbox(arma_mod06.resid.values, lags=30)['lb_pvalue'],
              'critial':np.array([0.05]*30)}).set_index('lags').plot().update_layout(height=350, width=1300).show()
# plt.plot(sm.stats.diagnostic.acorr_ljungbox(arma_mod00.resid.values, lags=30)[1],'b')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 4
#       1 # Ljung-Box test
#       2 # H0: lags are not correlated
#       3 pd.DataFrame({'lags':range(30), 'pvalue':sm.stats.diagnostic.acorr_ljungbox(arma_mod06.resid.values, lags=30)['lb_pvalue'],
# ----> 4               'critial':np.array([0.05]*30)}).set_index('lags').plot().update_layout(height=350, width=1300).show()
#       5 # plt.plot(sm.stats.diagnostic.acorr_ljungbox(arma_mod00.resid.values, lags=30)[1],'b')
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %% [markdown]
# Values of the residuals TS are not correlated

# %%
# Durbin_Watson statistic
# if there is no correlation in a sample then Stat ~= 2
sm.stats.durbin_watson(arma_mod06.resid.values)
# Out:
# np.float64(1.9799687811889861)

# %% [markdown]
# ### Unbiasedness test

# %%
# Wilcoxon test
# H0: obervations are not biased
stat, p = stats.wilcoxon(arma_mod06.resid.values)
print('Statistic: %f\npvalue: %.2f' %(stat, p))
# Out:
# Statistic: 104570.000000
# pvalue: 0.02

# %% [markdown]
# Residuals are biased!

# %% [markdown]
# ### Normality test

# %%
# H0: sample comes from a normal distribution
stats.normaltest(arma_mod06.resid)
# Out:
# NormaltestResult(statistic=np.float64(211.51491722523662), pvalue=np.float64(1.1752203537356653e-46))

# %%
## q-qPlot
fig = plt.figure()
res = stats.probplot(arma_mod06.resid, dist="norm", plot = plt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 ## q-qPlot
# ----> 2 fig = plt.figure()
#       3 res = stats.probplot(arma_mod06.resid, dist="norm", plot = plt)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# * Hypothesis of normality can be rejected because of heavy tails of the real distribution

# %% [markdown]
# ### Forecast of Validation Period (in-sample)
# Despite of theoretical issues of the built model we can generate forecast for the time series

# %%
# Static forecasting = one-step-ahead
# fig, ax = plt.subplots()

# fig = arma_mod06.plot_predict(start='2008-10-01', end='2008-12-31', ax=ax, dynamic=False)
# draw_arima_forecast(ts_wage_boxcox[['wage_boxcox']], arima_011_311, start_dt='2008-01-01', end_dt='2017-12-01')
draw_arima_forecast(pd.DataFrame(dta), arma_mod06) # , start_dt=pd.to_datetime('2007-01-18 00:00:00')) #, end_dt='2008-12-31')

# frc_arma = arma_mod06.predict('2008-12-30', '2008-12-31', dynamic=False)
# print(frc_arma)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 6
#       1 # Static forecasting = one-step-ahead
#       2 # fig, ax = plt.subplots()
#       3
#       4 # fig = arma_mod06.plot_predict(start='2008-10-01', end='2008-12-31', ax=ax, dynamic=False)
#       5 # draw_arima_forecast(ts_wage_boxcox[['wage_boxcox']], arima_011_311, start_dt='2008-01-01', end_dt='2017-12-01')
# ----> 6 draw_arima_forecast(pd.DataFrame(dta), arma_mod06) # , start_dt=pd.to_datetime('2007-01-18 00:00:00')) #, end_dt='2008-12-31')
#       8 # frc_arma = arma_mod06.predict('2008-12-30', '2008-12-31', dynamic=False)
#       9 # print(frc_arma)
#
# Cell In[7], line 30, in draw_arima_forecast(ts, arima_model, start_dt, end_dt)
#      15   end_dt = ts_wage_boxcox.index.max()
#      17 # Plot data points and predictions
#      18 fig = ts.loc[start_dt:].merge(
#      19     forecast[start_dt:end_dt],
#      20       how = 'left', left_index = True, right_index = True
#      21       ).merge(
#      22           forecast_dy[start_dt:],
#      23           how = 'left', left_index = True, right_index = True
#      24       ).merge(
#      25         forecast_ci,
#      26         how = 'left', left_index = True, right_index = True
#      27       ).merge(
#      28         forecast_dy_ci,
#      29         how = 'left', left_index = True, right_index = True
# ---> 30       ).plot().update_layout(height=350, width=1300).show()
#      32 return fig
#
# AttributeError: 'Axes' object has no attribute 'update_layout'

# %% [markdown]
# ### Forecast of Future Period (out-of-sample)

# %%
# fig, ax = plt.subplots(figsize=(25,5),  linewidth=3.0)
frc_arma = arma_mod06.forecast(steps=28) #pd.to_datetime('2009-02-01 00:00:00'))
frc_arma
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# 684    3.683174
# 685    5.073314
# 686    4.575562
# 687    3.944950
# 688    4.901736
# 689    4.525140
# 690    3.916451
# 691    3.916451
# 692    3.916451
# 693    3.916451
# 694    3.916451
# 695    3.916451
# 696    3.916451
# 697    3.916451
# 698    3.916451
# 699    3.916451
# 700    3.916451
# 701    3.916451
# 702    3.916451
# 703    3.916451
# 704    3.916451
# 705    3.916451
# 706    3.916451
# 707    3.916451
# 708    3.916451
# 709    3.916451
# 710    3.916451
# 711    3.916451
# Name: predicted_mean, dtype: float64

# %% [markdown]
# # ACF and PACF of ARIMA models
#
# Example1 : ACF and PACF for AR(1) model
#
# <img src='https://github.com/aromanenko/ATSF/blob/main/pic/AR1.PNG?raw=1'>
#
# Example2 : ACF and PACF for AR(2) model
#
# <img src='https://github.com/aromanenko/ATSF/blob/main/pic/AR2.PNG?raw=1'>
#
#
# Example3 : ACF and PACF for AR(1) and MA(1) model
#
# <img src='https://github.com/aromanenko/ATSF/blob/main/pic/ARMA_1_1.PNG?raw=1'>
#
#
#
# Example4 : ACF and PACF for MA(1) model
#
# <img src='https://github.com/aromanenko/ATSF/blob/main/pic/MA2_1.PNG?raw=1'>
#
# <!--
# Example5 : ACF and PACF for MA(2) model
#
# <img src='https://github.com/aromanenko/ATSF/blob/main/pic/MA2_2.PNG?raw=1'> -->

# %% [markdown]
# # Online forecasting with ARIMA
# Look how (even simple) ARIMA model performs in online aprroach

# %%
def online_ARMA(x, h, Params): # see statsmodels.ARMA

  # Параметры алгоритма
  p = Params['p']
  q = Params['q']

  rng = pd.date_range(x.index[-1]+timedelta(1),x.index[-1]+timedelta(h))
  frc_ts = pd.Series(index = x.index.append(rng))

  for t in x.index: #
      y = deepcopy(x.loc[:t])
      if not y.dropna().empty:
          try:
              arma_mod = sm.tsa.ARIMA(y.dropna(), (p,0, q)).fit()
              frc_ts.loc[t+timedelta(h)] = arma_mod.forecast(h)[0][-1] # get last forecasting value
              # print(arma_mod.forecast(h)[0][-1])
          except Exception:
              print("Can not fit model p=%d, q=%d at step t=%s!" % (p, q, t))
  return frc_ts.ffill()

# %%
# Caution: takes a lot of time
p = 0
q = 6
h = 1
ts_num = 1

frc_ts = online_ARMA(x=dta, h=h, Params={'p':p, 'q': q})
# Out:
# Can not fit model p=0, q=6 at step t=2007-01-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-01-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-02-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-03-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-04-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-05-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-06-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-12 00:00:00!
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# Can not fit model p=0, q=6 at step t=2007-07-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-07-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-08-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-09-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-10-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-11-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2007-12-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-01-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-02-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-03-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-04-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-05-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-06-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-07-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-08-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-09-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-10-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-11-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-01 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-27 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-28 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-29 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-30 00:00:00!
# Can not fit model p=0, q=6 at step t=2008-12-31 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-02 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-03 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-04 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-05 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-06 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-07 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-08 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-09 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-10 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-11 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-12 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-13 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-14 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-15 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-16 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-17 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-18 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-19 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-20 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-21 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-22 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-23 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-24 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-25 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-26 00:00:00!
# Can not fit model p=0, q=6 at step t=2009-01-30 00:00:00!

# %%
# fair forecast by ARIMA model
plot_ts = ts[[ts.columns[ts_num]]]
# frc_ts = FRC_TS[Models[model]]
plot_ts["{0}; ARMA p={1}, q={2}".format(ts.columns[ts_num],p,q)] = frc_ts

plot_ts.plot() # :250
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11812\4126291526.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_ts["{0}; ARMA p={1}, q={2}".format(ts.columns[ts_num],p,q)] = frc_ts
# <Axes: xlabel='Timestamp'>

# %%
# Quality
print('MACAPE: %.2f'% qualityMAPE(plot_ts.iloc[:,0], plot_ts.iloc[:,1])[0])
print('RMSE: %.1f'% qualityRMSE(plot_ts.iloc[:,0], plot_ts.iloc[:,1])[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Quality
# ----> 2 print('MACAPE: %.2f'% qualityMAPE(plot_ts.iloc[:,0], plot_ts.iloc[:,1])[0])
#       3 print('RMSE: %.1f'% qualityRMSE(plot_ts.iloc[:,0], plot_ts.iloc[:,1])[0])
#
# NameError: name 'qualityMAPE' is not defined

# %% [markdown]
# # Conclusion
# ## Self-check questions
#   1. How to define differencing order $d, D$ for a time series?
#   2. What is autocorrelation function (ACF)?
#   3. What does coefficient of correlation show?
#   4. What is partial autocorrelation function (PACF)?  What does coefficient of partial correlation show?
#   5. How do ACF and PACF help to choose $q, Q$ and $p, P$ of ARMA model?

# %% [markdown]
# **Materialsf**
# * Автокорреляционный анализ при построении ARMA, ARIMA
#     - Магнус Я.Р., Катышев П.К., Пересецкий А.А. Эконометрика. Начальный курс., глава 11
#     - http://www.autobox.com/cms/index.php/blog/entry/build-or-make-your-own-arima-forecasting-model
#     - А.И. Кобзарь. Прикладная математическая статистика. Для инженеров и научных работников http://zyurvas.narod.ru/knyhy2/Kobzar_Prikl_stat.djvu
# * Autocorrelation analysis
#
#   - https://online.stat.psu.edu/stat510/lesson/2
#
#   - http://www.autobox.com/cms/index.php/blog/entry/build-or-make-your-own-arima-forecasting-model
